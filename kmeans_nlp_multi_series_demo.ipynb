# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %%
import pandas as pd

# Load CSV
df = pd.read_csv("demo_multi_series.csv")

# Clean column names (removes spaces)
df.columns = df.columns.str.strip()

# Check column names
print("Columns:", df.columns)

# Convert date column to datetime (adjust name if needed)
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])
elif 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])

# Show first rows
print(df.head())
# Out:
# Columns: Index(['series_id', 'timestamp', 'value'], dtype='str')
#   series_id   timestamp        value
# 0   id_1000  2016-01-01  1012.500694
# 1   id_1000  2016-01-02  1158.500099
# 2   id_1000  2016-01-03   983.000099
# 3   id_1000  2016-01-04  1675.750496
# 4   id_1000  2016-01-05  1586.250694

# %%
df.head()
df.columns
# Out:
# Index(['series_id', 'timestamp', 'value'], dtype='str')

# %%
df.columns.tolist()
# Out:
# ['series_id', 'timestamp', 'value']

# %%
print(df.columns)
# Out:
# Index(['series_id', 'timestamp', 'value'], dtype='str')

# %%
dir()
# Out:
# ['In',
#  'KMeans',
#  'Out',
#  'StandardScaler',
#  'TfidfVectorizer',
#  '_',
#  '_5',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'df',
#  'exit',
#  'get_ipython',
#  'kmeans',
#  'np',
#  'open',
#  'pd',
#  'plt',
#  'quit',
#  'scaler']

# %%
df.columns
# Out:
# Index(['series_id', 'timestamp', 'value'], dtype='str')

# %%
vectorizer = TfidfVectorizer()
