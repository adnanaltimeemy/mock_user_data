# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
# Load the dataset
df = pd.read_csv("air_quality_valencia.csv")

# Display first rows
df.head()
# Out:
#               datetime   so2   co    no  ...    o3  veloc.  direc.  pm2.5
# 0  2019-01-01 00:00:00   8.0  0.2   3.0  ...  16.0     0.5   262.0   19.0
# 1  2019-01-01 01:00:00   8.0  0.1   2.0  ...   6.0     0.6   248.0   26.0
# 2  2019-01-01 02:00:00   8.0  0.1  11.0  ...   3.0     0.3   224.0   31.0
# 3  2019-01-01 03:00:00  10.0  0.1  15.0  ...   3.0     0.2   220.0   30.0
# 4  2019-01-01 04:00:00  11.0  0.1  16.0  ...   3.0     0.4   221.0   30.0
#
# [5 rows x 11 columns]

# %%
# Dataset info
df.info()

# Summary statistics
df.describe()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  43824 non-null  str
#  1   so2       41988 non-null  float64
#  2   co        40555 non-null  float64
#  3   no        43206 non-null  float64
#  4   no2       43206 non-null  float64
#  5   pm10      41832 non-null  float64
#  6   nox       43206 non-null  float64
#  7   o3        42614 non-null  float64
#  8   veloc.    42987 non-null  float64
#  9   direc.    43552 non-null  float64
#  10  pm2.5     41832 non-null  float64
# dtypes: float64(10), str(1)
# memory usage: 4.5 MB
# datetime       0
# so2         1836
# co          3269
# no           618
# no2          618
# pm10        1992
# nox          618
# o3          1210
# veloc.       837
# direc.       272
# pm2.5       1992
# dtype: int64

# %%
print(df.dtypes)
# Out:
# datetime        str
# so2         float64
# co          float64
# no          float64
# no2         float64
# pm10        float64
# nox         float64
# o3          float64
# veloc.      float64
# direc.      float64
# pm2.5       float64
# dtype: object

# %%
df.columns = df.columns.str.strip()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Example dataset
data = {
    "age": [25, 30, 35, 40],
    "salary": [50000, 60000, 65000, 70000]
}

df = pd.DataFrame(data)

# Define X (features)
X = df[["age", "salary"]]

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print(X_scaled)
# Out:
# [[-1.34164079 -1.52127766]
#  [-0.4472136  -0.16903085]
#  [ 0.4472136   0.50709255]
#  [ 1.34164079  1.18321596]]

# %%
print(X_scaled)
print(X_scaled.shape)
# Out:
# [[-1.34164079 -1.52127766]
#  [-0.4472136  -0.16903085]
#  [ 0.4472136   0.50709255]
#  [ 1.34164079  1.18321596]]
# (4, 2)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)

df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
score = silhouette_score(X_scaled, df['Cluster'])
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.07710898129796892

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['age', 'salary', 'Cluster'], dtype='str')

# %%
list(df.columns)
# Out:
# ['age', 'salary', 'Cluster']

# %%
print(kmeans.cluster_centers_.shape)
print(features)
# Out:
# (3, 2)
# ['NO2', 'O3', 'PM10', 'PM2.5', 'CO']

# %%
df.to_csv("valencia_air_quality_clustered.csv", index=False)
